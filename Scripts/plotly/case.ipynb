# %%
import psycopg2

# %%
conn = psycopg2.connect(
    host="localhost",  
    port=5432,  
    user="postgres",  
    password="2501",  
    dbname="postgres"  
)

cursor=conn.cursor()

# %%
import pandas as pd

file_path = r"C:\\Users\\V\\Downloads.xlsx"
xls = pd.ExcelFile(file_path)
print(xls.sheet_names)  # Покажет, какие листы есть в файле
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 file_path = r"C:\\Users\\V\\Downloads.xlsx"
# ----> 4 xls = pd.ExcelFile(file_path)
#       5 print(xls.sheet_names)  # Покажет, какие листы есть в файле
#
# File c:\Users\V\Desktop\da_course\.venv\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# ...

# %%
file_path = "C:\\Users\\V\\Downloads.xlsx"

# %%
import pandas as pd

file_path = r"C:\Users\V\Documents.xlsx"  # Укажи свой путь
try:
    xls = pd.ExcelFile(file_path)
    print("Листы в файле:", xls.sheet_names)
except Exception as e:
    print("Ошибка:", e)
# Out:
# Ошибка: [Errno 2] No such file or directory: 'C:\\Users\\V\\Documents.xlsx'

# %%
import os

file_path = r"C:\Users\V\Documents\adventure_works.xlsx"  # Укажи свой путь
if os.path.exists(file_path):
    print("Файл найден!")
else:
    print("Файл НЕ найден!")
# Out:
# Файл найден!

# %%
import pandas as pd

file_path = r"C:\Users\V\Documents\adventure_works.xlsx" 
xls = pd.ExcelFile(file_path)
print(xls.sheet_names)  # Покажет, какие листы есть в файле
# Out:
# ['Customers', 'Products', 'Territory', 'Sales', 'ProductCategory', 'ProductSubCategory']

# %%
import pandas as pd

file_path = r"C:\Users\V\Documents\adventure_works.xlsx"  # Новый путь к файлу
df_customers = pd.read_excel(file_path, sheet_name="Customers")
print(df_customers.head())  # Посмотрим на данные
# Out:
#    CustomerKey  GeographyKey                 Name  BirthDate MaritalStatus  \
# 0        11602           135           Larry Gill 1977-04-13             S
# 1        11603           244    Geoffrey Gonzalez 1977-02-06             S
# 2        11610           269        Blake Collins 1975-04-23             S
# 3        12517           133         Alexa Watson 1977-08-25             S
# 4        12518           161  Jacquelyn Dominguez 1977-09-27             S
#
#   Gender  YearlyIncome  NumberChildrenAtHome Occupation  HouseOwnerFlag  \
# 0      M         30000                     0   Clerical               0
# 1      M         30000                     0   Clerical               0
# 2      M         30000                     0   Clerical               0
# 3      F         30000                     0   Clerical               0
# 4      F         30000                     0   Clerical               0
#
#    NumberCarsOwned        AddressLine1 AddressLine2                Phone  \
# ...

# %%
import pandas as pd

file_path = r"C:\Users\V\Documents\adventure_works.xlsx"  # Путь к файлу
df_customers = pd.read_excel(file_path, sheet_name="Customers")  # Читаем лист "Customers"

csv_path = r"C:\Users\V\Documents\customers.csv"  # Куда сохранить
df_customers.to_csv(csv_path, index=False)  # Сохраняем без индексов

print(f"Файл сохранён: {csv_path}")
# Out:
# Файл сохранён: C:\Users\V\Documents\customers.csv

# %%
import os
print(os.path.exists(r"C:\Users\Public\Documents\customers.csv"))
# Out:
# False

# %%
import os
file_path = r"C:\Users\V\Documents\customers.csv"
print(os.path.exists(file_path))  # Должно вывести True
print(file_path)  # Убедись, что путь отображается корректно
# Out:
# True
# C:\Users\V\Documents\customers.csv
